# %%
import yfinance as yf 

MSFT = yf.Ticker("MSFT") 

MSFT
# Out:
# yfinance.Ticker object <MSFT>

# %%
hist = MSFT.history(period = "24mo")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-03-23 00:00:00-04:00  233.282615  236.779544  232.870058  233.371017
# 2021-03-24 00:00:00-04:00  233.636232  233.783569  231.151055  231.288574
# 2021-03-25 00:00:00-04:00  231.131367  232.742312  227.467453  228.223801
# 2021-03-26 00:00:00-04:00  227.447829  232.516418  227.447829  232.290482
# 2021-03-29 00:00:00-04:00  232.398554  232.604840  227.772005  231.072479
# ...                               ...         ...         ...         ...
# 2023-03-16 00:00:00-04:00  265.209991  276.559998  263.279999  276.200012
# 2023-03-17 00:00:00-04:00  278.260010  283.329987  276.320007  279.429993
# 2023-03-20 00:00:00-04:00  276.980011  277.480011  269.850006  272.230011
# 2023-03-21 00:00:00-04:00  274.880005  275.000000  269.519989  273.779999
# 2023-03-22 00:00:00-04:00  273.399994  281.040009  272.179993  272.290009
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-03-23 00:00:00-04:00  31638400        0.0           0.0
# 2021-03-24 00:00:00-04:00  25620100        0.0           0.0
# 2021-03-25 00:00:00-04:00  34061900        0.0           0.0
# 2021-03-26 00:00:00-04:00  25479900        0.0           0.0
# 2021-03-29 00:00:00-04:00  25227500        0.0           0.0
# ...                             ...        ...           ...
# 2023-03-16 00:00:00-04:00  54768800        0.0           0.0
# 2023-03-17 00:00:00-04:00  69492200        0.0           0.0
# 2023-03-20 00:00:00-04:00  43466600        0.0           0.0
# 2023-03-21 00:00:00-04:00  34558700        0.0           0.0
# 2023-03-22 00:00:00-04:00  34731100        0.0           0.0
#
# [504 rows x 7 columns]

# %%
hist["Close"]
# Out:
# Date
# 2021-03-23 00:00:00-04:00    233.371017
# 2021-03-24 00:00:00-04:00    231.288574
# 2021-03-25 00:00:00-04:00    228.223801
# 2021-03-26 00:00:00-04:00    232.290482
# 2021-03-29 00:00:00-04:00    231.072479
#                                 ...
# 2023-03-16 00:00:00-04:00    276.200012
# 2023-03-17 00:00:00-04:00    279.429993
# 2023-03-20 00:00:00-04:00    272.230011
# 2023-03-21 00:00:00-04:00    273.779999
# 2023-03-22 00:00:00-04:00    272.290009
# Name: Close, Length: 504, dtype: float64

# %%
data = hist["Close"]

data.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
data.describe()
# Out:
# count    504.000000
# mean     271.863647
# std       29.135868
# min      213.114120
# 25%      247.960239
# 50%      267.049454
# 75%      292.598083
# max      339.075531
# Name: Close, dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 0
variance = 1
sigma = math.sqrt(variance)

x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
std = data.std()
std
# Out:
# 29.135868341237966

# %%
mean = data.mean()
mean
# Out:
# 271.86364740038675

# %%
x = np.linspace(mean - 3*std, mean + 3*std, 100)
y = stats.norm.pdf(x, mean, std)

plt.plot(x, y)
plt.show()
